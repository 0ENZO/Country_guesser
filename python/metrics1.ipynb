# %%
from image import *
import numpy as np
(x_train, y_train), (x_test, y_test) = import_dataset()
# Out:
# ['jordanie', 'palestine', 'soudan']

# %%
epochs = 200
it = 500

np_arr = np.array([len(x_train[0]), 3])
npl = np.ctypeslib.as_ctypes(np_arr)
model = create_mlp_model(npl)

show_graphs(model, epochs, iterations_count=it)

# %%
save_mlp_model(model, f"MLP_0hl_24px_0.01a_{epochs}e_{it}it")

# %%
destroy_mlp_model(model)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# C:\Users\ERWANS~1\AppData\Local\Temp/ipykernel_6608/1559780824.py in <module>
# ----> 1 destroy_mlp_model(model)
#
# ~\Desktop\Country_guesser\python\mlp.py in destroy_mlp_model(model)
#      88     mylib.destroy_mlp_model.argtypes = [c_void_p]
#      89     mylib.destroy_mlp_model.restype = None
# ---> 90     mylib.destroy_mlp_model(model)
#      91
#      92
#
# OSError: exception: access violation reading 0xFFFFFFFFFFFFFFFF
